# %% [markdown]
# # Line Chart | 1016

# %% [markdown]
# - https://www.python-graph-gallery.com/scatter-plot/
# - https://www.linkedin.com/in/maruf-hossain-682213150/
# - https://github.com/Maruf2309

# %% [markdown]
# - A line chart displays the evolution of one or several numeric variables
# - It is one of the most common chart type, so it can be build using any python viz library, like matplotlib, seaborn or plotly
# - Making a simple line chart with matplotlib is pretty straightforward thanks to the plot() function
# - If you provide only a series of values, it will consider that these values are ordered and will use values from 1 to n to create the X axis.

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# create data
values = np.cumsum(np.random.randn(1000, 1))  # cumsum: Return the cumulative sum of the elements along a given axis

# Use the Plot Function
plt.plot(values)

# %% [markdown]
# # Line chart with matplotlib

# %% [markdown]
# - A line chart or line graph is a type of chart which displays information as a series of data points called ‘markers’ connected by straight line segments.
# - It is similar to a scatter plot except that the measurement points are ordered (typically by their x-axis value) and joined with straight line segments.
# - This post will show how to plot a basic line chart using matplotlib.

# %% [markdown]
# ## Basic Lineplot

# %% [markdown]
# - You can create a basic line chart with the plot() function of matplotlib library
# - If you give only a serie of values, matplotlib will consider that these values are ordered and will use values from 1 to n to create the X axis

# %%
# Create Data
values = np.cumsum(np.random.randn(1000, 1))

# Use the plot function
plt.plot(values)
# Show the graph
plt.show()

# %% [markdown]
# ## Seaborn Customization

# %% [markdown]
# - For a more trendy look, you can use the set_theme() function of seaborn library
# - You will automatically get the look of figure

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Use Seaborn Style
sns.set_theme()

# create data
values = np.cumsum(np.random.randn(1000, 1))

# Use the plot function
plt.plot(values)
# Show the graph
plt.show()

# %% [markdown]
# ## Use lineplot with unordered data

# %% [markdown]
# - You can also make a line chart from 2 series of values (X and Y axis)
# - However, make sure that your X axis values are ordered! If not, you will get this kind of figure (figure 3)

# %%
# import the iris dataset
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# plotting
plt.plot('sepal_width', 'sepal_length', data=df)     # Figure 3
plt.show()

# %% [markdown]
# ## Use lineplot with ordered data

# %% [markdown]
# - If your X data is ordered, then you will get a similar figure as figure 1

# %%
# libraries and data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset
df = pd.DataFrame({'xvalues': range(1,101), 'yvalues': np.random.randn(100)})

# Ploting
plt.plot('xvalues', 'yvalues', data=df)
plt.show()

# %% [markdown]
# # Line chart customization with matplotlib

# %% [markdown]
# - The previous post explains how to create a linechart. This post aims to show how to customize it using matplotlib.

# %% [markdown]
# ## Custom Line Color

# %% [markdown]
# - To custom color, just use the color argument!
# - Note that you can add transparency to the color with the alpha argument (0=transparent, 1=opaque).

# %%
# Dataset
df = pd.DataFrame({'x_values': range(1, 11), 'y_values':np.random.randn(10)})

# Draw plot
plt.plot('x_values', 'y_values', data=df, color='skyblue')
plt.show()

# Draw line chart by modifiying transparency of the line       # 2nd graph is transperent
plt.plot('x_values', 'y_values', data=df, color='skyblue', alpha=0.3)
plt.show()

# %% [markdown]
# ## Custom Line Style

# %% [markdown]
# - You can choose between different line styles with the linestyle argument

# %%
# Dataset
df = pd.DataFrame({'x_values': range(1, 11), 'y_values': np.random.randn(10) })

# Draw line chart with dashed line
plt.plot('x_values', 'y_values', data=df, linestyle='dashed')
plt.show()

# %% [markdown]
# - The following examples show different types of line styles

# %%
plt.plot( [1,1.1,1,1.1,1], linestyle='-' , linewidth=4)
plt.text(1.5, 1.3, "linestyle='-' ", horizontalalignment='left', size='medium', color='C0', weight='semibold')
plt.plot( [2,2.1,2,2.1,2], linestyle='--' , linewidth=4 )
plt.text(1.5, 2.3, "linestyle  = '--' ", horizontalalignment='left', size = 'medium', color='C1', weight='semibold')
plt.plot([3.3, 1.3, 3.1, 3], linestyle= '-.', linewidth= 4)
plt.text(1.5, 3.3, "linestyle = '-.' ", horizontalalignment='left', size='medium', color='C2', weight='semibold')
plt.plot([4, 4.1, 4, 4.1,4], linestyle=":", linewidth=4)
plt.text(1.5, 4.3, "linestyle=':' ", horizontalalignment= 'left', size='medium', color='C3', weight = 'semibold')
plt.axis('off')
plt.show()

# %%
plt.text(1.5, 1.3, "linestyle = '-' ", horizontalalignment='left', size='medium', color='C0', weight='semibold')
# Out:
# Text(1.5, 1.3, "linestyle = '-' ")

# %%
plt.plot( [2,2.1,2,2.1,2], linestyle='--' , linewidth=4 )

# %%
plt.text(1.5, 2.3, "linestyle  = '--' ", horizontalalignment='left', size = 'medium', color='C1', weight='semibold')
# Out:
# Text(1.5, 2.3, "linestyle  = '--' ")

# %%
plt.plot( [1,1.1,1,1.1,1], linestyle='-' , linewidth=4)
plt.text(1.5, 1.3, "linestyle = '-' ", horizontalalignment='left', size='medium', color='C0', weight='semibold')
plt.plot( [2,2.1,2,2.1,2], linestyle='--' , linewidth=4 )
plt.text(1.5, 2.3, "linestyle = '--' ", horizontalalignment='left', size='medium', color='C1', weight='semibold')
plt.plot( [3,3.1,3,3.1,3], linestyle='-.' , linewidth=4 )
plt.text(1.5, 3.3, "linestyle = '-.' ", horizontalalignment='left', size='medium', color='C2', weight='semibold')
plt.plot( [4,4.1,4,4.1,4], linestyle=':' , linewidth=4 )
plt.text(1.5, 4.3, "linestyle = ':' ", horizontalalignment='left', size='medium', color='C3', weight='semibold')
plt.axis('off')
plt.show()

# %%
plt.text(1.5, 3.3, "linestyle = '-.' ", horizontalalignment='left', size='medium', color='C2', weight='semibold')
# Out:
# Text(1.5, 3.3, "linestyle = '-.' ")

# %% [markdown]
# ## Custom Line Width

# %% [markdown]
# - Finally you can custom the line width as well using linewidth argument.

# %%
# Required Libraries already called
# Dataset
df = pd.DataFrame({'x_values': range(1,11), 'y_values': np.random.randn(10)})

# Modify the linewidht of graph
plt.plot('x_values', 'y_values', data=df, linewidth=22)
plt.show()

# %% [markdown]
# ## Connected Scatterplot

# %%
# libraries
# Data
df = pd.DataFrame({
    'x_axis': range(1, 10),
    'y_axis': np.random.randn(9)*80 + range(1, 10)
})

plt.plot('x_axis', 'y_axis', data=df, linestyle="-", marker='o')
plt.show()

# %%
# Dataset
df = pd.DataFrame({
    'x_axis': range(1, 11),
    'y_axis': np.random.randn(10)*10 + range(1,11)  # random must be lenth of range(1-11) 10 and as per earlier defined range(1,11)
})
# Plot
plt.plot('x_axis', 'y_axis', data=df, linestyle = '-', marker = 'o')  # values (x & y); data, linestyle & marker
plt.show()

# %% [markdown]
# ## Two types of connected scatterplot

# %% [markdown]
# - There are two types of connected scatterplot, and it often creates confusion.
# - The first is simply a lineplot with dots added on top of it. It takes as input 2 numeric variables only.
# - The second shows the relationship between 2 numeric variables across time. It requires 3 numeric variables as input.

# %% [markdown]
# # Connected scatterplot with Seaborn

# %% [markdown]
# - Building a connected scatterplot with Seaborn looks pretty much the same as for a line chart, so feel free to visit the related section.
# - Here are a few examples to remind the basics and understand how to customize the markers.

# %% [markdown]
# ## Seaborn style on matplotlib plot

# %% [markdown]
# - Matplotlib allows you to make absolutely any type of chart. However the chart style of matplotlib library is not as fancy as seaborn style.
# - It is possible to benefit from seaborn library style when plotting charts in matplotlib.
# - You just need to load the seaborn library and use seaborn set_theme() function!

# %%
# Create Data
df = pd.DataFrame({'x_axis':range(1,101), 'y_axis':np.random.randn(100)*15+ range(1,101), 'z': (np.random.randn(100)*15+ range(1,101))*2})
# Plot with Matplotlib
plt.plot('x_axis', 'y_axis', data=df, marker='o', color ='mediumvioletred')
plt.title('Simple Line Chart', loc='left')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %%
# Dataset
df = pd.DataFrame({
    'x_axis': range(1,101),
    'y_axis': np.random.randn(100),    
})
# Ploting
plt.plot('x_axis', 'y_axis', data=df, marker='o', color='orange')
plt.show()

# %% [markdown]
# ### Seaborn Theme

# %%
# Library
from matplotlib import pyplot as plt 
import numpy as np 
import pandas as pd

# Dataset
df = pd.DataFrame({
    'x_axis': range(1,101),
    'y_axis': np.random.randn(100)*15 + range(1,101),
    'z': (np.random.randn(100)*15 + range(1,101))*2
})

# Load Seaborn & Set theme for better visualization
import seaborn as sns 
sns.set_theme()

# Plot
plt.plot('x_axis', 'y_axis', data=df, marker='o', color='mediumvioletred')
plt.title('Plot Using Seaborn Theme')
plt.show()

# %%
# Library
from matplotlib import pyplot as plt 
import numpy as np 
import pandas as pd

# Dataset
df = pd.DataFrame({
    'x_axis': range(1,101),
    'y_axis': np.random.randn(100)*15 + range(1,101),
    'z': (np.random.randn(100)*15 + range(1,101))*2
})

# Plot
plt.plot('x_axis', 'y_axis', data=df, marker='o', color='mediumvioletred')
plt.title('Plot Without Seaborn Theme', loc='left')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # Splitting the graph area with subplots in matplotlib

# %% [markdown]
# - This post aims to explain how to display several graphs at the same figure using one of the matplotlib functions : subplot
# - It can be really useful to split your graphic window into several parts in order to display several charts at the same time.
# - With matplotlib, this can be done using subplot() function. It is possible to display your graphics in several rows or several columns, or both.
# - You can also control the size of each part. The examples below should allow you to understand how to use subplot() function:

# %% [markdown]
# ### 2 Columns

# %% [markdown]
# - In order to split the figure you should give 3-digit integer as a parameter to subplot().
# - The integers describe the position of subplots: first digit is the number of rows, the second is the number of columns, and the third is the index of the subplot.
# - In the example below, subplot(121) indicates a figure with 1 row and 2 columns, and the following graph will be plotted at index 1. index starts at 1 in the upper left corner and increases to the right.

# %%
# 2 Columns  :: 2 plow will be shown as side by side as columns
# Libraries
from matplotlib import pyplot as plt 
import numpy as np
import pandas as pd 

# Dataset
df = pd.DataFrame({
    'x_values': range(1,101),
    'y_values': np.random.randn(100)*15 + range(1,101),
    'z_values': (np.random.randn(100)*15+range(1,101))*2
})

# Cut your window in 1 & 2 columns, and start a plot in the first part
plt.subplot(121)   # row:col:index   one row with 2 col/part and one index   1:row, 2:col & 1 means plot will be drawn at first plot
plt.plot('x_values','y_values', data=df, marker='o', alpha =0.4)  # Alpha params for changing transperency
plt.title('A plot with two lines')

# And Now add something at second plot
plt.subplot(122)       # last 2 is index so, plot will be drawn at 2nd plot
plt.plot('x_values', 'z_values', data=df, linestyle ='none', marker='o', color='orange', alpha=0.3)
plt.title('Ploting at 2nd plot')

# Show the plot
plt.show()

# %% [markdown]
# ## 2 Rows

# %% [markdown]
# - Unlike the previous example, this one shows the figure with 2 rows.

# %%
# Libraries
import matplotlib.pyplot as plt  # or from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd

# Dataset
df = pd.DataFrame({
    'x_axis': range(1,101),
    'y_axis': np.random.randn(100)*15 + range(1,101),
    'z_axis': (np.random.randn(100)*15 + range(1,101))*2
})

# First Line:
plt.subplot(221)             # So, 211 is equivalent to nrows=2, ncols=1, plot_number=1 or 1st line
plt.plot('x_axis','y_axis', data=df, linestyle='None', marker='o', color='blue', alpha = 0.4)
plt.title('A subplot with two lines')

# Second Line:
plt.subplot(212)             # So, 212 is equivalent to nrows=2, ncols=1, plot_number=2 or 2nd line
plt.plot('x_axis', 'z_axis', data=df, linestyle='None', marker = 'o', alpha=0.4)
plt.title('2nd Graph', loc='right')


# Show Plot
plt.show()

# %% [markdown]
# ## Shared Axis

# %% [markdown]
# - You can make the plot to share the x or y axis with setting sharex and/or sharey parameters to True.
# - The axis will have the same limits, ticks, and scale as the axis of the shared axes.
# - Notice that the index is not given to subplot() function in the below example.
# - The fist graph is indicated with axes[0] and the second one with axes[1].

# %%
## Share Axis
# Dataset
df = pd.DataFrame({
    'x_values': range(1,101),
    'y_values': np.random.randn(100)*15 + range(1,101),
    'z_values': (np.random.randn(100)*15 + range(1,101))*2
})

# Initialize the figure, here we share X & Y axis
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)
axes[0].plot('x_values', 'y_values', data=df, marker='o', alpha = 0.4)  # First Plot
axes[1].plot('x_values', 'z_values', data=df, linestyle='None', marker='o', color='orange', alpha= 0.3)  # Second Plot
axes[0].title.set_text('This 2 plot have the same limit for the Y axis')     # Title at the second plot

# Plot Show
plt.show()

# %%
# Dataset
df = pd.DataFrame({
    'x_values': range(1,101),
    'y_values': np.random.randn(100)*15 + range(1,101),
    'z_values': (np.random.randn(100)*15 + range(1,101))*2
})

# Initialize the figure, here we have X & Y axis
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)
axes[0].plot('x_values', 'y_values', data=df, marker='o', alpha = 0.4)  # First Plot  
axes[1].plot('x_values', 'z_values', data=df, linestyle = '-', marker='o', color='orange', alpha= 0.6)
axes [1].title.set_text('Writing Title for 2nd graph')


# Plow Show
plt.show()

# %% [markdown]
# ## 2 Rows and 2 Columns

# %% [markdown]
# - This example provides a reproducible code to draw 4 graphs in the same figure: 2 rows x 2 columns.

# %%
# Dataset
df = pd.DataFrame({
    'x_values': range(1,101),
    'y_values': np.random.randn(100)*15 + range(1,101),
    'z_values': (np.random.randn(100)*15 + range(1,101))* 2
})

# Cut the window with 2 rows & 2 columns
plt.subplot(221)       # nrows, ncols & index
plt.plot('x_values', 'y_values', data=df, linestyle='None', marker='o', color='green', alpha=0.4)
plt.plot('x_values', 'z_values', data=df, linestyle = '-', marker='o', color='red', alpha= 0.6)
plt.title('Overplotting')

# Plot Show
plt.show()

# %%
# Dataset
df = pd.DataFrame({
    'x_values': range(1,101),
    'y_values': np.random.randn(100)*15 + range(1,101),
    'z_values': (np.random.randn(100)* 15 + range(1,101))* 2
})

# Cut the  window with 2 rows & 2 columns  
## Ploting (221, 222, 223, 224)
plt.subplot(221)
plt.plot('x_values', 'y_values', data=df, linestyle ='-', marker='o', color='red', alpha= 0.6)
plt.subplot(222)   # idex 2/ right side
plt.plot('x_values', 'z_values', data=df, linestyle='-', marker='o', color='orange', alpha=0.4)
plt.subplot(223)
plt.plot('x_values', 'z_values', data=df, linestyle='None', marker='o', color='green', alpha=0.5)
plt.subplot(224)
plt.plot('x_values', 'y_values', data=df, linestyle='dashed', marker='o', color='red', alpha=0.3)

# Plot Show
plt.show()

# %% [markdown]
# # Title

# %% [markdown]
# - You can give a title to the figure itself as well as the subplots in the figure.
# - In the example below, matplotlib title() function is used to give title to 4 subplots separately, and suptitle() is used to give a superior title, figure title.

# %%
# Dataset
df = pd.DataFrame({
    'x_axis': range(1,101),
    'y_axis': np.random.randn(100) * 15 + range(1,101),
    'z_axis': (np.random.randn(100)*15 + range(1,101))*2
})

# Initializing a Figure
fig = plt.figure()

# Do a 2x2 Chart
plt.subplot(221)
plt.plot('x_axis', 'y_axis', data=df, linestyle='dashed', marker='^', color='red', alpha=0.5)
plt.title('Title of Fig A', fontsize= 12, color='gray', loc='left', style='italic')

plt.subplot(222)
plt.plot('x_axis', 'z_axis', data=df, linestyle='-', marker='o', color='C3', alpha=0.6)
plt.title('Title of Fig B', fontsize= 12, color='0', loc='right', style='italic')  # color 0 = black

plt.subplot(223)
plt.plot('x_axis', 'z_axis', data=df, linestyle='None', marker='3', color='blue', alpha=0.7)
plt.title('Title of Fig C', fontsize=10, color='grey', loc='left', style='italic')

plt.subplot(224)
plt.plot('x_axis', 'z_axis', data=df, linestyle='dashed', marker='^', color='green', alpha=0.6)
plt.title('Title of Fig D', fontsize=10, color='grey', loc='left', style='italic')

# Add a Title
plt.suptitle("Common Four Plot", y= 1.02)       # value of y (here its 1.02) its control the top margin, The more the value, more the margin. Suptile required when so many graph within a window, suptile is common for all



# Show the Graph
plt.show()

# %% [markdown]
# # Custom Proportion

# %% [markdown]
# - In order to customize the proportions of subplots on the figure, you can use subplot2grid() function which lets subplot to occupy multiple cells. You can see all parameters in matplotlib documentation. These are the parameters used in our examples:
#
# - shape : Number of rows and of columns of the grid in which to place axis
# - loc : Row number and column number of the axis location within the grid
# - rowspan : Number of rows for the axis to span to the right
# - colspan : Number of columns for the axis to span downwards

# %%
df=pd.DataFrame({'x_values': range(1,101), 'y_values': np.random.randn(100)*15+range(1,101), 'z_values': (np.random.randn(100)*15+range(1,101))*2 })

# Plot 1
ax1 = plt.subplot2grid((2,2), (0,0), colspan=2)
ax1.plot('x_values', 'y_values', data=df, linestyle ='None', marker='o', color='grey', alpha=0.4)

# Plot 2
ax2 = plt.subplot2grid((2,2), (1,0), colspan=1)   # rightward measurement
ax2.plot('x_values', 'z_values', data=df, linestyle = '-', marker='o', color='red', alpha=0.6)

# Plot 3
ax3 = plt.subplot2grid((2,2), (1,1), colspan=1)
ax3.plot('x_values', 'z_values', data=df, linestyle='-', marker='o', color='purple', alpha=0.3)



# Plow Show
plt.show()

# %% [markdown]
# # Line Chart with Several Lines

# %% [markdown]
# - This example shows how to make a line chart with several lines. Each line represents a set of values, for example one set per group.
# - To make it with matplotlib we just have to call the plot function several times (one time per group).

# %%
# Data
df = pd.DataFrame({
    'x_values': range(1,11), 
    'y1_values': np.random.randn(10),
    'y2_values': np.random.randn(10)+range(1,11),  # first 10 random value will be generated & from the range (1,11)/ 1 to 10 number will be randomly generated and being added with primarily random generated number
    'y3_values': np.random.randn(10)+range(11,21)
})

# Multiple Line Plot
plt.plot('x_values', 'y1_values', data=df, marker='o', markerfacecolor='blue', markersize=10, color='skyblue', linewidth=4)
plt.plot('x_values', 'y2_values', data=df, marker='', color='olive', linewidth=2, label='2nd line')                                              # linestyle='-', not applicable
plt.plot('x_values', 'y3_values', data=df, marker='', color='red', linewidth=3, linestyle='dashed', label="Custom Name")

# Show the Legend
plt.legend()


# Show the Graph
plt.show()

# %% [markdown]
# # Highlight a line in line plot

# %% [markdown]
# - In order to avoid the creation of a spaghetti plot, it is a good practice to highlight the group(s) that interests you the most in your line chart.
# - It allows the reader to understand your point quickly, instead of struggling to decipher hundreds of lines.
# - This post will show how to highight a line in a line chart using matplotlib.

# %% [markdown]
# - he trick for highlighting a specific group is to plot all the groups with thin and discreet lines first.
# - Then, replot the interesting group(s) with strong and really visible line(s). Moreover, it is good practice to annotate this highlighted group with a custom annotation.
# - The following example shows how to do that by using the color, linewidth and alpha parameters of the plot() function of matplotlib.

# %% [markdown]
# ### Codes

# %%
# Make a data frame
df = pd.DataFrame({
    'x': range(1,11),
    'y1': np.random.randn(10),
    'y2': np.random.randn(10) + range(1,11),
    'y3': np.random.randn(10) + range(11,21),
    'y4': np.random.randn(10) + range(6,16),
    'y5': np.random.randn(10) + range(4,14) + (0,0,0,0,0,0,0,-3,-8,-6),
    'y6': np.random.randn(10) + range(2,12),
    'y7': np.random.randn(10) + range(5,15),
    'y8': np.random.randn(10) + range(4,14)
})

# Create the Style of Plot
plt.style.use('seaborn-darkgrid')

# Set Figure Size
my_dpi = 96
plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi = my_dpi)  # Explanation

# Plot Multiple Line                                         # Explanation
for column in df.drop('x', axis=1):
    plt.plot(df['x'], df[column], marker='', color='grey', linewidth=1, alpha=0.4)

# Now re do the interesting curve, but biger with distinct color
plt.plot(df['x'],df['y5'], marker='^', color='orange', linewidth=5, alpha=0.7)       # Keep the x as fixed line & change y5 only

# Change x axis limit
plt.xlim(0,12)

# Let's annotate the plot
num=0
for i in df.values[9][1:]:  # 9 means index val like (0 to 9); 1: = all columns
    num+=1
    name=list(df)[num]
    if name != 'y5':
        plt.text(10.2, i, name, horizontalalignment='left', size='small', color='grey')

# And add a special annotation for the group we are interested in
plt.text(10.2, df.y5.tail(1), 'Mr Orange', horizontalalignment='left', size='small', color='orange')  # Naming the last point of y5

# Add titles
plt.title('Evoluation of Mr Orange vs other Students', loc='left', fontsize=12, fontweight=0, color='blue')
plt.xlabel("Time")
plt.ylabel("Score")

# Plot Show
plt.show()

# %%
df
# Out:
#     x        y1         y2         y3         y4         y5         y6  \
# 0   1  1.933303  -0.677985  10.306727   4.852691   4.234453   2.493042
# 1   2 -0.919109   2.700110  10.841295   6.259326   5.998669   2.752208
# 2   3 -0.265427   5.042966  13.191891   8.475749   5.402517   6.559795
# 3   4  1.314410   2.548097  16.018418  10.712340   7.685043   4.846164
# 4   5  0.757517   3.642444  14.512891  12.425475   7.472739   6.303199
# 5   6  1.546855   7.234325  17.114058   9.973093   7.691563   7.084928
# 6   7 -0.527953   5.499704  17.862865  11.651521  10.023425   8.538677
# 7   8 -0.107448   8.028042  19.130780  12.934564   7.188019   9.601950
# 8   9 -1.711585   9.237741  20.657675  14.562797   4.604780  10.153501
# 9  10  0.752129  12.471517  18.673994  14.959231   7.382821  11.714670
#
#           y7         y8
# 0   6.050877   2.295537
# 1   5.621222   4.673537
# 2   6.636202   8.100201
# 3   9.036170   5.862505
# 4   9.435361   7.656830
# 5   9.583743   8.582409
# ...

# %% [markdown]
# ## Reference

# %% [markdown]
# - https://www.python-graph-gallery.com/194-split-the-graphic-window-with-subplot
# - https://matplotlib.org/2.1.2/tutorials/intermediate/gridspec.html

# %% [markdown]
# - https://www.python-graph-gallery.com/194-split-the-graphic-window-with-subplot
