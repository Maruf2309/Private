# %% [markdown]
# # General Practice

# %% [markdown]
# - Classification Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Ploting

# %%
df.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# # Joint Plot

# %%
import seaborn as sns
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=df, hue='Species')

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.jointplot(x='PetalLengthCm', y='PetalWidthCm', data=df, hue='Species', height=10)

# %%
sns.boxenplot(y='PetalWidthCm', data=df,)
# Out:
# <AxesSubplot:ylabel='PetalWidthCm'>

# %%
sns.boxenplot(x='Species', y='PetalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.kdeplot(data=df, x='SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.kdeplot(data=df, x='PetalWidthCm', hue='Species')        # hue Represent category, present 3 chategory in more meaningful way
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df.drop('Id', axis=1), hue='Species', height=9)

# %% [markdown]
# - As per graph, its proven that there will be good relationship between PatelLenghCm & PetalwidthCm, so this choosing this criteria can be best choice. There is good pattern
# - So, if we randomly take a flower to verify, amonge three we will be able to more clearly identify the PetalLength & PetalWidgh
